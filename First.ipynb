# %% [markdown]
# <a href="https://colab.research.google.com/github/NubeEra-ResearchNDevelopments/EmployeeAttendence-AI/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome")
# Out:
# Welcome
